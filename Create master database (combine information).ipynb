# %% [markdown]
# ## Create master database of player information (market values and stats)

# %%
import pandas as pd
import numpy as np
import time

# %%
# Load base dataframe

combined = pd.read_csv("combined_table.csv")

# %%
market_values[market_values['pid'] == 133964].T
# Out:
#                           12345            13234            14254
# teamid                     6195             6195             6195
# number                       24               24               24
# name            Lorenzo Insigne  Lorenzo Insigne  Lorenzo Insigne
# pid                      133964           133964           133964
# main_pos               attacker         attacker         attacker
# position              Left Wing        Left Wing        Left Wing
# dob                  1991-06-04       1991-06-04       1991-06-04
# age                          24               25               26
# nat1                      Italy            Italy            Italy
# nat2                        NaN              NaN              NaN
# height                     1.63             1.63             1.63
# foot                      right            right            right
# teamsince                   NaN              NaN              NaN
# prevteam                    NaN              NaN              NaN
# prevteamid                  NaN              NaN              NaN
# transferfee                   0                0                0
# contractuntil               NaN              NaN       2022-06-30
# marketval               1.5e+07          2.5e+07          3.5e+07
# prevmarketval           1.5e+07          2.5e+07          2.8e+07
# team                 SSC Napoli       SSC Napoli       SSC Napoli
# season                    15/16            16/17            17/18
# teamurl              ssc-neapel       ssc-neapel       ssc-neapel
# year                       2015             2016             2017
# current_team         SSC Napoli       SSC Napoli       SSC Napoli
# current_teamid             6195             6195             6195
# country                   Italy            Italy            Italy

# %%
# Load additional dataframes

market_values = pd.read_csv("market_values.csv")
tm_by_year = pd.read_csv("career_by_year.csv")
tm_summary = pd.read_csv("career_summary.csv")
s_stats = pd.read_csv("player_stats.csv")
s_info = pd.read_csv("player_info.csv")
teams_list = pd.read_csv("teams.csv")

# %%
# Combine MPG, PPG, apps, assists, league_name from tm_by_year

# Create a subset dataframe & select only the 2016 info for each player

#tm_by_year['pid'] = tm_by_year['pid'].apply(pd.to_numeric, errors = 'coerce')

tm_by_year['total_points'] = tm_by_year['apps'] * tm_by_year['PPM'] # To calculate the total team points earned

tm_by_year_summary = tm_by_year.groupby(['pid','year'])[['minutes','total_points','apps',
                                                         'assists','goals','conceded_goals',
                                                         'clean_sheets']].sum().copy()

tm_by_year_summary.reset_index(inplace = True)

tm_2016 = tm_by_year_summary[tm_by_year_summary['year'] == 2016].copy()

tm_2016['MPM'] = tm_2016['minutes'] / tm_2016['apps']
tm_2016['PPM'] = tm_2016['total_points'] / tm_2016['apps']
tm_2016['GPM'] = tm_2016['goals'] / tm_2016['apps']
tm_2016['CS_R'] = tm_2016['clean_sheets'] / tm_2016['apps']
tm_2016['GAPM'] = tm_2016['conceded_goals'] / tm_2016['apps']

tm_2016.drop('year', axis = 1, inplace = True)

tm_2016.columns = ['pid','mins_2016','points_2016','apps_2016','assists_2016','goals_2016','conceded_2016',
                 'clean_sheets_2016','MPM_2016','PPM_2016','GPM_2016','CS_R','GAPM']

tm_2016.head(3)
# Out:
#     pid  mins_2016  points_2016  apps_2016  assists_2016  goals_2016  \
# 36   26     1050.0        20.01       11.0           NaN         NaN
# 54   68      454.0        13.98        9.0           NaN         1.0
# 72   80      450.0        15.00        5.0           NaN         NaN
#
#     conceded_2016  clean_sheets_2016   MPM_2016  PPM_2016  GPM_2016      CS_R  \
# 36           18.0                1.0  95.454545  1.819091       NaN  0.090909
# 54            NaN                NaN  50.444444  1.553333  0.111111       NaN
# 72            7.0                1.0  90.000000  3.000000       NaN  0.200000
#
#         GAPM
# 36  1.636364
# 54       NaN
# 72  1.400000

# %%
# Find the league where a player played most games in 2016

tm_club_summary = tm_by_year.groupby(['pid','league_name','year'])[['apps']].sum().copy()
tm_club_summary.reset_index(inplace = True)

tm_club_2016 = tm_club_summary[tm_club_summary['year'] == 2016].copy()

tm_club_2016.sort_values(['pid', 'apps'], ascending=[True, False], inplace=True)

tm_club_2016 = tm_club_2016.drop_duplicates(subset=['pid'], keep='first')

tm_club_2016.head(6)
# Out:
#      pid   league_name    year  apps
# 76    26  1.Bundesliga  2016.0   7.0
# 152   68           MLS  2016.0   6.0
# 187   80  1.Bundesliga  2016.0   3.0
# 251  107           MLS  2016.0   4.0
# 301  132      HET Liga  2016.0   1.0
# 411  488    EFL Trophy  2016.0   4.0

# %%
# Create a field that counts how many champions league games the player played in

tm_ucl_summary = tm_by_year.groupby(['pid','league_name','year'])[['apps']].sum().copy()
tm_ucl_summary.reset_index(inplace = True)

tm_ucl_2016 = tm_ucl_summary[(tm_ucl_summary['year'] == 2016) & (tm_ucl_summary['league_name'] == "Champions League")].copy()

# tm_ucl_2016.sort_values(['pid', 'apps'], ascending=[True, False], inplace=True)

# tm_ucl_2016 = tm_club_2016.drop_duplicates(subset=['pid'], keep='first')
tm_ucl_2016.drop(tm_ucl_2016[tm_ucl_2016['apps'].isnull()].index, inplace=True)

# Change column name to ucl_2016_apps
tm_ucl_2016.rename(columns={'apps':'ucl_2016_apps'}, inplace=True)

# %%
# Add the player's most common league in 2016 to the dataframe & champions league games played

tm_2016 = pd.merge(tm_2016, tm_club_2016[['pid','league_name']], how = 'left', on = 'pid')
tm_2016 = pd.merge(tm_2016, tm_ucl_2016[['pid','ucl_2016_apps']], how = 'left', on = 'pid')

# %%
tm_2016.head()
# Out:
#    pid  mins_2016  points_2016  apps_2016  assists_2016  goals_2016  \
# 0   26     1050.0        20.01       11.0           NaN         NaN
# 1   68      454.0        13.98        9.0           NaN         1.0
# 2   80      450.0        15.00        5.0           NaN         NaN
# 3  107       34.0         1.00        4.0           NaN         NaN
# 4  132       18.0         1.00        1.0           NaN         NaN
#
#    conceded_2016  clean_sheets_2016   MPM_2016  PPM_2016  GPM_2016      CS_R  \
# 0           18.0                1.0  95.454545  1.819091       NaN  0.090909
# 1            NaN                NaN  50.444444  1.553333  0.111111       NaN
# 2            7.0                1.0  90.000000  3.000000       NaN  0.200000
# 3            NaN                NaN   8.500000  0.250000       NaN       NaN
# 4            NaN                NaN  18.000000  1.000000       NaN       NaN
#
#        GAPM   league_name  ucl_2016_apps
# 0  1.636364  1.Bundesliga            2.0
# 1       NaN           MLS            NaN
# 2  1.400000  1.Bundesliga            NaN
# 3       NaN           MLS            NaN
# 4       NaN      HET Liga            NaN

# %%
market_values.head(5)
# Out:
#    teamid  number           name       pid  main_pos     position         dob  \
# 0  7831.0     1.0   Michael Theo   39657.0    keeper       Keeper  1981-02-11
# 1  7831.0    21.0    Jamie Young   13435.0    keeper       Keeper  1985-08-25
# 2  7831.0    36.0  Andre Jannese  403669.0    keeper       Keeper  1996-10-28
# 3  7831.0    13.0     Jade North   29583.0  defender  Centre-Back  1982-01-07
# 4  7831.0    33.0    Luke DeVere   80716.0  defender  Centre-Back  1989-11-05
#
#     age       nat1       nat2    ...      contractuntil marketval  \
# 0  34.0  Australia     Greece    ...         2018-06-30  700000.0
# 1  29.0    England  Australia    ...                NaN  100000.0
# 2  18.0  Australia        NaN    ...                NaN       NaN
# 3  33.0  Australia        NaN    ...                NaN  400000.0
# 4  25.0  Australia     France    ...         2017-06-30  400000.0
#
#   prevmarketval           team  season        teamurl    year  \
# 0      750000.0  Brisbane Roar   15/16  brisbane-roar  2015.0
# 1       50000.0  Brisbane Roar   15/16  brisbane-roar  2015.0
# 2           NaN  Brisbane Roar   15/16  brisbane-roar  2015.0
# 3      350000.0  Brisbane Roar   15/16  brisbane-roar  2015.0
# 4      800000.0  Brisbane Roar   15/16  brisbane-roar  2015.0
#
#         current_team  current_teamid    country
# 0      Brisbane Roar          7831.0  Australia
# 1      Brisbane Roar          7831.0  Australia
# 2  Brisbane Roar U21         26205.0  Australia
# 3      Brisbane Roar          7831.0  Australia
# 4      Brisbane Roar          7831.0  Australia
#
# [5 rows x 26 columns]

# %%
# Merge dataframes

master = pd.merge(combined, tm_2016, how = 'left', on = 'pid')

# %%
master.shape
# Out:
# (3138, 46)

# %%
master.head()
# Out:
#    teamid  number             name    pid  main_pos     position         dob  \
# 0  8054.0     1.0  Andrew Redmayne  51975    keeper       Keeper  1989-01-13
# 1  8054.0     5.0      Jordy Buijs  31111  defender  Centre-Back  1988-12-28
# 2  8054.0     4.0   Alex Wilkinson  43128  defender  Centre-Back  1984-08-13
# 3  8054.0    22.0  Sebastian Ryall  58120  defender  Centre-Back  1989-07-18
# 4  8054.0     7.0    Michael Zullo  55444  defender    Left-Back  1988-11-09
#
#     age         nat1   nat2      ...       goals_2016 conceded_2016  \
# 0  28.0    Australia    NaN      ...              NaN          32.0
# 1  28.0  Netherlands    NaN      ...              1.0           NaN
# 2  33.0    Australia    NaN      ...              NaN           NaN
# 3  28.0    Australia    NaN      ...              NaN           NaN
# 4  28.0    Australia  Italy      ...              NaN           NaN
#
#   clean_sheets_2016   MPM_2016  PPM_2016  GPM_2016      CS_R      GAPM  \
# 0               4.0  83.111111  1.337778       NaN  0.444444  3.555556
# 1               NaN  86.800000  1.999500      0.05       NaN       NaN
# 2               NaN  89.206897  2.478621       NaN       NaN       NaN
# 3               NaN  53.933333  2.534667       NaN       NaN       NaN
# 4               NaN  91.071429  2.535714       NaN       NaN       NaN
#
#    league_name ucl_2016_apps
# 0     A-League           NaN
# 1     A-League           NaN
# 2     A-League           NaN
# 3     A-League           NaN
# 4     A-League           NaN
#
# [5 rows x 46 columns]

# %%
# Merge master with tm summary

# Columns to merge

tm_career = tm_summary[['pid','MPG','PPM','apps','assists','clean_sheets','conceded_goals','goals','intl_caps',
                  'intl_goals','minutes']].copy()

# rename columns for merge

tm_career.columns = ['pid','MPG_career','PPM_career','apps_career','assists_career','clean_sheets_career',
                    'conceded_goals_career','goals_career','intl_caps','intl_goals','minutes_career']

# %%
# Merge dataframes

master = pd.merge(master, tm_career, how = 'left', on = 'pid')

# %%
master.shape
# Out:
# (3138, 56)

# %%
# Merge master with squawka match stats

# Columns to merge

s_stats.head()
# Out:
#    index    idn  attack  defense  possession  goalkeeping  score  match_id  \
# 0      0   67.0    0.00   -27.30       -1.43          0.0 -28.73      8445
# 1      1  375.0    0.00    55.21        4.42          0.0  59.63      8445
# 2      2  523.0   10.19    -8.28       -7.88          0.0  -5.97      8445
# 3      3  728.0    0.00    14.45       17.12          0.0  31.57      8445
# 4      4  807.0    0.00    -2.04        7.05          0.0   5.01      8445
#
#    start_year season_code  goals  assists  team_id  state   age  sub result  \
# 0        2014       14/15      0        0    315.0      1  30.0    0      L
# 1        2014       14/15      0        0     46.0      1  31.0    0      W
# 2        2014       14/15      0        0     46.0      1  24.0    0      W
# 3        2014       14/15      0        0    315.0      1  33.0    0      L
# 4        2014       14/15      0        0     46.0      1  34.0    0      W
#
#    clean_sheet
# 0            0
# 1            1
# 2            1
# 3            0
# 4            1

# %%
# Create a subset dataframe & select only the 2016 info for each player

#tm_by_year['pid'] = tm_by_year['pid'].apply(pd.to_numeric, errors = 'coerce')

#s_stats['total_points'] = tm_by_year['apps'] * tm_by_year['PPM'] # To calculate the total team points earned

s_stats_summary = s_stats.groupby(['idn','start_year'])[['attack','defense','possession',
                                                         'goalkeeping','score']].mean().copy()

s_stats_summary.reset_index(inplace = True)

s_stats_2016 = s_stats_summary[s_stats_summary['start_year'] == 2016].copy()

s_stats_2016.drop('start_year', axis = 1, inplace = True)

s_stats_2016.columns = ['idn','attack_2016','defense_2016','poss_2016','gk_2016','score_2016']

s_stats_2016.head(3)
# Out:
#    idn  attack_2016  defense_2016  poss_2016  gk_2016  score_2016
# 1  1.0    23.701562     -0.696562  -2.101875      0.0   20.903125
# 6  7.0     0.176667     14.289167   2.426389      0.0   16.892222
# 9  8.0    12.770400      5.610400   8.293600      0.0   26.674400

# %%
# Merge dataframes

master = pd.merge(master, s_stats_2016, how = 'left', on = 'idn')

# %%
master.shape
# Out:
# (3138, 61)

# %%
s_info.shape
# Out:
# (297116, 17)

# %%
master.columns
# Out:
# Index([u'teamid', u'number', u'name', u'pid', u'main_pos', u'position', u'dob',
#        u'age', u'nat1', u'nat2', u'height', u'foot', u'teamsince', u'prevteam',
#        u'prevteamid', u'transferfee', u'contractuntil', u'marketval',
#        u'prevmarketval', u'team', u'season', u'teamurl', u'year',
#        u'current_team', u'current_teamid', u'country', u'marketval_2016',
#        u'country_2016', u'name_dob', u'check', u'squawka_name_dob', u'idn',
#        u'mins_2016', u'points_2016', u'apps_2016', u'assists_2016',
#        u'goals_2016', u'conceded_2016', u'clean_sheets_2016', u'MPM_2016',
#        u'PPM_2016', u'GPM_2016', u'CS_R', u'GAPM', u'league_name',
#        u'ucl_2016_apps', u'MPG_career', u'PPM_career', u'apps_career',
#        u'assists_career', u'clean_sheets_career', u'conceded_goals_career',
#        u'goals_career', u'intl_caps', u'intl_goals', u'minutes_career',
#        u'attack_2016', u'defense_2016', u'poss_2016', u'gk_2016',
#        u'score_2016'],
#       dtype='object')

# %%
s_info_select.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 18882 entries, 0 to 297110
# Data columns (total 6 columns):
# idn         18882 non-null float64
# height_s    17522 non-null float64
# weight      17223 non-null float64
# bmi         18882 non-null float64
# age         18882 non-null float64
# count       18882 non-null float64
# dtypes: float64(6)
# memory usage: 1.0 MB

# %%
# Merge dataframes

s_info_select = s_info[['idn','height','weight','bmi','age']]

s_info_select.columns = ['idn','height_s','weight','bmi','age']

s_info_select = s_info_select.drop_duplicates()

# %%
s_info.head()
# Out:
#    index   age   bmi         country         dob  first_name  height  \
# 0      0  27.0  21.2           Wales  1989-02-07        Neil   175.0
# 1      1  32.0  23.0           Wales  1984-08-23      Ashley   183.0
# 2      2  25.0  22.2         England  1991-05-22        Kyle   185.0
# 3      3  31.0  23.0          Poland  1985-04-18      Lukasz   190.0
# 4      4  28.0  22.6  Korea Republic  1989-01-24  Sung-yueng   187.0
#
#    last_name              name    position  shirt_num    state  \
# 0     Taylor       Neil Taylor    Defender        0.0  playing
# 1   Williams   Ashley Williams    Defender        0.0  playing
# 2    Bartley      Kyle Bartley    Defender        0.0    bench
# 3  Fabianski  Lukasz Fabianski  Goalkeeper        1.0  playing
# 4         Ki     Ki Sung-yueng  Midfielder        4.0  playing
#
#            surname  team_id team_name  weight     idn
# 0      Neil Taylor     46.0   Swansea    65.0   817.0
# 1  Ashley Williams     46.0   Swansea    77.0   810.0
# 2     Kyle Bartley     46.0   Swansea    76.0   382.0
# 3        Fabianski     46.0   Swansea    83.0   375.0
# 4               Ki     46.0   Swansea    79.0  3691.0

# %%
# Review duplicated entries

s_info_select['count'] = s_info_select.groupby('idn')['idn'].transform('count')
s_info_select[s_info_select['count'] != 1].sort_values(by = 'idn').head()
# Out:
#         idn  height_s  weight   bmi   age  count
# 112874  1.0     187.0    80.0  22.9  29.0    3.0
# 96502   1.0     187.0    80.0  22.9  28.0    3.0
# 295809  1.0     187.0    78.0  22.3  30.0    3.0
# 46230   7.0     191.0    84.0  23.0  32.0    3.0
# 190322  7.0     191.0    84.0  23.0  33.0    3.0

# %% [markdown]
# Entries are duplicated since player weights have changed with age. I want to make a dataframe whereby the oldest age is the entry that remains.

# %%
# Create empty dataframe of just player ids

s_info_unique_ids = s_info_select[['idn']]
s_info_unique_ids = s_info_unique_ids.drop_duplicates()
s_info_unique_ids.head(2)
# Out:
#      idn
# 0  817.0
# 1  810.0

# %%
def most_recent_height(value):
    temp_df = s_info_select[s_info_select['idn'] == value] # Creates a temporary dataframe for the player id
    temp_df = temp_df.sort_values(by = 'age', ascending = False) # Makes the most recent entry 1st
    temp_df = temp_df.reset_index() # To ensure we can retrieve the first row
    height = temp_df.loc[0,'height_s']
    return height

def most_recent_weight(value):
    temp_df = s_info_select[s_info_select['idn'] == value] # Creates a temporary dataframe for the player id
    temp_df = temp_df.sort_values(by = 'age', ascending = False) # Makes the most recent entry 1st
    temp_df = temp_df.reset_index() # To ensure we can retrieve the first row
    weight = temp_df.loc[0,'weight']
    return weight

def most_recent_bmi(value):
    temp_df = s_info_select[s_info_select['idn'] == value] # Creates a temporary dataframe for the player id
    temp_df = temp_df.sort_values(by = 'age', ascending = False) # Makes the most recent entry 1st
    temp_df = temp_df.reset_index() # To ensure we can retrieve the first row
    bmi = temp_df.loc[0,'bmi']
    return bmi

s_info_unique_ids['height_s'] = s_info_unique_ids['idn'].apply(most_recent_height)
s_info_unique_ids['weight'] = s_info_unique_ids['idn'].apply(most_recent_weight)
s_info_unique_ids['bmi'] = s_info_unique_ids['idn'].apply(most_recent_bmi)

# %%
master = pd.merge(master, s_info_unique_ids, how = 'left', on = 'idn')

# %%
master.head(30)
# Out:
#      teamid  number                     name     pid    main_pos  \
# 0    8054.0     1.0          Andrew Redmayne   51975      keeper
# 1    8054.0     5.0              Jordy Buijs   31111    defender
# 2    8054.0     4.0           Alex Wilkinson   43128    defender
# 3    8054.0    22.0          Sebastian Ryall   58120    defender
# 4    8054.0     7.0            Michael Zullo   55444    defender
# 5    8054.0    23.0              Rhyan Grant  108108    defender
# 6    8054.0    12.0             Aaron Calver  255162    defender
# 7    8054.0     NaN              Paulo Retre  257685  midfielder
# 8    8054.0     6.0         Joshua Brillante  171307  midfielder
# 9    8054.0    13.0          Brandon O'Neill  218371  midfielder
# 10   8054.0    10.0           Milos Ninkovic   48740  midfielder
# 11   8054.0    14.0             Alex Brosque   18626  midfielder
# 12   8054.0    17.0             David Carney   10387    attacker
# 13   8054.0     9.0                     Bobô   37944    attacker
# 14   8054.0    18.0               Matt Simon   43372    attacker
# 15  36100.0    20.0        Vedran Janjetovic   47194      keeper
# 16  36100.0     NaN                John Hall  215521      keeper
# 17  36100.0     1.0             Jerrad Tyson  123129      keeper
# 18  36100.0    18.0       Robert Cornthwaite   43089    defender
# 19  36100.0    22.0  Jonathan Aspropotamitis  363689    defender
# 20  36100.0     5.0           Brendan Hamill  147600    defender
# 21  36100.0     3.0              Jack Clisby  256915    defender
# 22  36100.0    25.0             Sam Gallaway  174350    defender
# 23  36100.0     NaN            Joshua Risdon  160614    defender
# 24  36100.0    19.0            Jacob Melling  181924  midfielder
# 25  36100.0     NaN           Roly Bonevacia  124885  midfielder
# 26  36100.0     7.0           Steven Lustica  127910  midfielder
# 27  36100.0    15.0            Kearyn Baccus  171419  midfielder
# 28  36100.0    11.0         Brendon Santalab   21202    attacker
# 29  36100.0     NaN            Álvaro Cejudo   72779    attacker
#
#               position         dob   age         nat1          nat2  ...   \
# 0               Keeper  1989-01-13  28.0    Australia           NaN  ...
# 1          Centre-Back  1988-12-28  28.0  Netherlands           NaN  ...
# 2          Centre-Back  1984-08-13  33.0    Australia           NaN  ...
# 3          Centre-Back  1989-07-18  28.0    Australia           NaN  ...
# 4            Left-Back  1988-11-09  28.0    Australia         Italy  ...
# 5           Right-Back  1991-02-26  26.0    Australia           NaN  ...
# 6           Right-Back  1996-01-12  21.0    Australia           NaN  ...
# 7   Defensive Midfield  1993-03-04  24.0    Australia      Portugal  ...
# 8     Central Midfield  1993-03-25  24.0    Australia         Italy  ...
# 9     Central Midfield  1994-04-12  23.0    Australia           NaN  ...
# 10  Attacking Midfield  1984-12-25  32.0       Serbia           NaN  ...
# 11  Attacking Midfield  1983-10-12  33.0    Australia       Uruguay  ...
# 12           Left Wing  1983-11-30  33.0    Australia           NaN  ...
# 13      Centre-Forward  1985-01-09  32.0       Brazil           NaN  ...
# 14      Centre-Forward  1986-07-21  31.0    Australia           NaN  ...
# 15              Keeper  1987-08-20  30.0    Australia       Croatia  ...
# 16              Keeper  1994-10-23  22.0    Australia           NaN  ...
# 17              Keeper  1989-09-21  27.0    Australia           NaN  ...
# 18         Centre-Back  1985-10-24  31.0    Australia       England  ...
# 19         Centre-Back  1996-06-07  21.0    Australia        Greece  ...
# 20         Centre-Back  1992-09-18  24.0    Australia       Ireland  ...
# 21           Left-Back  1992-02-16  25.0    Australia           NaN  ...
# 22           Left-Back  1992-03-16  25.0    Australia           NaN  ...
# 23          Right-Back  1992-07-27  25.0    Australia           NaN  ...
# 24  Defensive Midfield  1995-04-04  22.0    Australia           NaN  ...
# 25    Central Midfield  1991-10-08  25.0      Curacao   Netherlands  ...
# 26    Central Midfield  1991-04-12  26.0    Australia       Croatia  ...
# 27    Central Midfield  1991-09-05  26.0    Australia  South Africa  ...
# 28           Left Wing  1982-09-09  35.0    Australia       Croatia  ...
# 29          Right Wing  1984-01-29  33.0        Spain           NaN  ...
#
#     intl_goals minutes_career attack_2016 defense_2016  poss_2016  gk_2016  \
# 0          0.0         7298.0    0.000000    -9.395556   3.576667      0.0
# 1          3.0        22132.0    5.535556    17.768889   4.896667      0.0
# 2          0.0        21819.0    2.198077    24.034615   3.050385      0.0
# 3          1.0        12415.0    0.242222     9.186667   1.485556      0.0
# 4          0.0         9834.0    4.073600    23.546400  -9.105600      0.0
# 5          NaN        11269.0   12.590000    23.530833 -11.027500      0.0
# 6          2.0         2045.0   -0.141667    29.253333  -3.883333      0.0
# 7          NaN         2546.0    0.318000    -8.046000   0.334000      0.0
# 8          0.0         7624.0    5.723478     7.532174   3.655217      0.0
# 9          0.0         4838.0    7.473750     6.725417   4.683750      0.0
# 10         0.0        19433.0   26.088000     6.613200  -5.732400      0.0
# 11         5.0        18281.0   21.962000    -1.770400  -1.106400      0.0
# 12         6.0        12397.0    9.064500     0.083500  -2.116500      0.0
# 13         0.0        24068.0   26.416154     3.875385 -10.516923      0.0
# 14         0.0        10735.0    2.056818    -0.974545  -2.791818      0.0
# 15         NaN        11550.0    0.000000    17.055455   2.131818      0.0
# 16         0.0          899.0    0.000000   -17.093333  11.886667      0.0
# 17         0.0         3095.0    0.000000   -18.888333   0.121667      0.0
# 18         3.0        12676.0    6.265333    11.092000   1.061333      0.0
# 19         0.0         3750.0   -0.173500    12.180000   2.384500      0.0
# 20         1.0         5773.0    3.030909    -4.271818  -0.410909      0.0
# 21         NaN         6856.0    8.255238    20.129524  -7.236667      0.0
# 22         NaN         4756.0         NaN          NaN        NaN      NaN
# 23         0.0        12400.0    7.421579     2.694737  -6.549474      0.0
# 24         0.0         2512.0    0.000000     7.220000  -4.980000      0.0
# 25         0.0        11988.0   12.450476     2.075238  -6.241905      0.0
# 26         3.0         6207.0    7.390000     1.180000  -4.972857      0.0
# 27         0.0         2909.0    6.280952     5.926667   3.164286      0.0
# 28         0.0         6637.0   22.540000    -5.095000  -3.062222      0.0
# 29         NaN        16437.0    6.260588    -4.681176  -3.157647      0.0
#
#    score_2016  height_s  weight   bmi
# 0   -5.818889     194.0    84.0  22.3
# 1   28.201111     182.0    80.0  24.2
# 2   29.283077     187.0    85.0  24.3
# 3   10.914444     180.0    75.0  23.1
# 4   18.514400     170.0    63.0  21.8
# 5   25.093333     174.0    74.0  24.4
# 6   25.228333     186.0    76.0  22.0
# 7   -7.394000     170.0    63.0  21.8
# 8   16.910870     177.0    73.0  23.3
# 9   18.882917     179.0    78.0  24.3
# 10  26.968800     180.0    75.0  23.1
# 11  19.085200     182.0    72.0  21.7
# 12   7.031500     181.0    70.0  21.4
# 13  19.774615     186.0    85.0  24.6
# 14  -1.709545     188.0    79.0  22.4
# 15  19.187273     187.0    84.0  24.0
# 16  -5.206667     195.0    83.0  21.8
# 17 -18.766667     189.0    85.0  23.8
# 18  18.418667     197.0    84.0  21.6
# 19  14.391000     188.0    76.0  21.5
# 20  -1.651818     185.0    79.0  23.1
# 21  21.148095     180.0    72.0  22.2
# 22        NaN     181.0    80.0  24.4
# 23   3.566842     167.0    70.0  25.1
# 24   2.240000     174.0    71.0  23.5
# 25   8.283810     171.0    65.0  22.2
# 26   3.597143     174.0    68.0  22.5
# 27  15.371905     180.0    75.0  23.1
# 28  14.382778     173.0    72.0  24.1
# 29  -1.578235     180.0    78.0  24.1
#
# [30 rows x 64 columns]

# %%
master.shape
# Out:
# (3138, 64)

# %%
master.columns
# Out:
# Index([u'teamid', u'number', u'name', u'pid', u'main_pos', u'position', u'dob',
#        u'age', u'nat1', u'nat2', u'height', u'foot', u'teamsince', u'prevteam',
#        u'prevteamid', u'transferfee', u'contractuntil', u'marketval',
#        u'prevmarketval', u'team', u'season', u'teamurl', u'year',
#        u'current_team', u'current_teamid', u'country', u'marketval_2016',
#        u'country_2016', u'name_dob', u'check', u'squawka_name_dob', u'idn',
#        u'mins_2016', u'points_2016', u'apps_2016', u'assists_2016',
#        u'goals_2016', u'conceded_2016', u'clean_sheets_2016', u'MPM_2016',
#        u'PPM_2016', u'GPM_2016', u'CS_R', u'GAPM', u'league_name',
#        u'ucl_2016_apps', u'MPG_career', u'PPM_career', u'apps_career',
#        u'assists_career', u'clean_sheets_career', u'conceded_goals_career',
#        u'goals_career', u'intl_caps', u'intl_goals', u'minutes_career',
#        u'attack_2016', u'defense_2016', u'poss_2016', u'gk_2016',
#        u'score_2016', u'height_s', u'weight', u'bmi'],
#       dtype='object')

# %%
master.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3138 entries, 0 to 3137
# Data columns (total 64 columns):
# teamid                   3138 non-null float64
# number                   3012 non-null float64
# name                     3138 non-null object
# pid                      3138 non-null object
# main_pos                 3138 non-null object
# position                 3138 non-null object
# dob                      3138 non-null object
# age                      3138 non-null float64
# nat1                     3138 non-null object
# nat2                     1020 non-null object
# height                   3122 non-null float64
# foot                     2963 non-null object
# teamsince                3128 non-null object
# prevteam                 3128 non-null object
# prevteamid               3073 non-null float64
# transferfee              3138 non-null float64
# contractuntil            3025 non-null object
# marketval                3138 non-null float64
# prevmarketval            3137 non-null float64
# team                     3138 non-null object
# season                   3138 non-null object
# teamurl                  3138 non-null object
# year                     3138 non-null float64
# current_team             3138 non-null object
# current_teamid           3138 non-null float64
# country                  3138 non-null object
# marketval_2016           3138 non-null float64
# country_2016             3138 non-null object
# name_dob                 3138 non-null object
# check                    3138 non-null int64
# squawka_name_dob         3138 non-null object
# idn                      3138 non-null float64
# mins_2016                3103 non-null float64
# points_2016              3103 non-null float64
# apps_2016                3103 non-null float64
# assists_2016             2017 non-null float64
# goals_2016               1963 non-null float64
# conceded_2016            343 non-null float64
# clean_sheets_2016        326 non-null float64
# MPM_2016                 3103 non-null float64
# PPM_2016                 3103 non-null float64
# GPM_2016                 1963 non-null float64
# CS_R                     326 non-null float64
# GAPM                     343 non-null float64
# league_name              3125 non-null object
# ucl_2016_apps            400 non-null float64
# MPG_career               2711 non-null float64
# PPM_career               3134 non-null float64
# apps_career              3136 non-null float64
# assists_career           2681 non-null float64
# clean_sheets_career      364 non-null float64
# conceded_goals_career    365 non-null float64
# goals_career             2728 non-null float64
# intl_caps                2135 non-null float64
# intl_goals               2135 non-null float64
# minutes_career           3136 non-null float64
# attack_2016              2854 non-null float64
# defense_2016             2854 non-null float64
# poss_2016                2854 non-null float64
# gk_2016                  2854 non-null float64
# score_2016               2854 non-null float64
# height_s                 3055 non-null float64
# weight                   3033 non-null float64
# bmi                      3138 non-null float64
# dtypes: float64(43), int64(1), object(20)
# memory usage: 1.6+ MB

# %%
# Clean columns

master['pid'] = master['pid'].apply(pd.to_numeric, errors = 'coerce')

# %%
# Convert date fields to datetime

date_fields = ['dob','teamsince','contractuntil']

for col in date_fields:
    master[col] = pd.to_datetime(master[col], format="%Y-%m-%d")

# %%
master.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3138 entries, 0 to 3137
# Data columns (total 64 columns):
# teamid                   3138 non-null float64
# number                   3012 non-null float64
# name                     3138 non-null object
# pid                      3138 non-null float64
# main_pos                 3138 non-null object
# position                 3138 non-null object
# dob                      3138 non-null datetime64[ns]
# age                      3138 non-null float64
# nat1                     3138 non-null object
# nat2                     1020 non-null object
# height                   3122 non-null float64
# foot                     2963 non-null object
# teamsince                3128 non-null datetime64[ns]
# prevteam                 3128 non-null object
# prevteamid               3073 non-null float64
# transferfee              3138 non-null float64
# contractuntil            3025 non-null datetime64[ns]
# marketval                3138 non-null float64
# prevmarketval            3137 non-null float64
# team                     3138 non-null object
# season                   3138 non-null object
# teamurl                  3138 non-null object
# year                     3138 non-null float64
# current_team             3138 non-null object
# current_teamid           3138 non-null float64
# country                  3138 non-null object
# marketval_2016           3138 non-null float64
# country_2016             3138 non-null object
# name_dob                 3138 non-null object
# check                    3138 non-null int64
# squawka_name_dob         3138 non-null object
# idn                      3138 non-null float64
# mins_2016                3103 non-null float64
# points_2016              3103 non-null float64
# apps_2016                3103 non-null float64
# assists_2016             2017 non-null float64
# goals_2016               1963 non-null float64
# conceded_2016            343 non-null float64
# clean_sheets_2016        326 non-null float64
# MPM_2016                 3103 non-null float64
# PPM_2016                 3103 non-null float64
# GPM_2016                 1963 non-null float64
# CS_R                     326 non-null float64
# GAPM                     343 non-null float64
# league_name              3125 non-null object
# ucl_2016_apps            400 non-null float64
# MPG_career               2711 non-null float64
# PPM_career               3134 non-null float64
# apps_career              3136 non-null float64
# assists_career           2681 non-null float64
# clean_sheets_career      364 non-null float64
# conceded_goals_career    365 non-null float64
# goals_career             2728 non-null float64
# intl_caps                2135 non-null float64
# intl_goals               2135 non-null float64
# minutes_career           3136 non-null float64
# attack_2016              2854 non-null float64
# defense_2016             2854 non-null float64
# poss_2016                2854 non-null float64
# gk_2016                  2854 non-null float64
# score_2016               2854 non-null float64
# height_s                 3055 non-null float64
# weight                   3033 non-null float64
# bmi                      3138 non-null float64
# dtypes: datetime64[ns](3), float64(44), int64(1), object(16)
# memory usage: 1.6+ MB

# %% [markdown]
# ## Save final data frame to CSV

# %%
# Convert dataframes to CSV

start_time=time.time()
start_time_stamp = str(start_time).replace(".","")
start_time_stamp

matched_file_name = "master_table_" + start_time_stamp + ".csv"

master.to_csv(matched_file_name, encoding="utf-8", index = False)
